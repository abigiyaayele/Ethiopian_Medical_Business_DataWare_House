# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine
import logging

# %%
# Function to load and analyze data
def analyze_data(file_path):
    try:
        df = pd.read_csv(file_path)
        print(f"Data from {file_path}")
        print("\nHead of the DataFrame:")
        display(df.head())
        print("\nInfo of the DataFrame:")
        display(df.info())
        print("\nDescribe the DataFrame:")
        display(df.describe(include='all'))
    except Exception as e:
        print(f"Error processing file {file_path}: {e}")

# Analyze cheMed dataset
print("Analyzing cheMed dataset")
analyze_data('../telegram_data_scrapper/output/data/cheMed.csv')
print("="*80)
# Out:
# Analyzing cheMed dataset
# Data from ../telegram_data_scrapper/output/data/cheMed.csv
#
# Head of the DataFrame:
#                                 signature  channel_id channel_name  msg_id  \
# 0  msg_iteration.0.user.CheMed123.post.97  1627056354    CheMed123      97
# 1  msg_iteration.1.user.CheMed123.post.96  1627056354    CheMed123      96
# 2  msg_iteration.2.user.CheMed123.post.95  1627056354    CheMed123      95
# 3  msg_iteration.3.user.CheMed123.post.94  1627056354    CheMed123      94
# 4  msg_iteration.4.user.CheMed123.post.93  1627056354    CheMed123      93
#
#                                              message  \
# 0  ⚠️Notice!\nDear esteemed customers,\nDue to fo...
# 1  Mela-One በውስጡ ሆርሞን ያለው ድንገተኛ ወሊድ መቆጣጠርያ ሲሆን ያለ...
# 2  አዚትሮማይሲን በሃኪም መድሃኒት ማዘዣ ከሚታዘዙ አንቲባዮቲኮች አንዱ ሲሆን...
# 3  Che-Med Trivia #3\n\nምግብና መጠጦች አንዳንድ መድሃኒቶች በደ...
# 4  Che-Med Trivia #2\n\nእንደ Ciprofloxacin, Doxycy...
#
#                                      cleaned_message  \
# ...

# %%
# Analyze Doctorset dataset
print("Analyzing Doctorset dataset")
analyze_data('../telegram_data_scrapper/output/data/Doctorset.csv')
print("="*80)
# Out:
# Analyzing Doctorset dataset
# Data from ../telegram_data_scrapper/output/data/Doctorset.csv
#
# Head of the DataFrame:
#                                  signature  channel_id channel_name  msg_id  \
# 0  msg_iteration.0.user.DoctorsET.post.864  1102021238    DoctorsET     864
# 1  msg_iteration.1.user.DoctorsET.post.863  1102021238    DoctorsET     863
# 2  msg_iteration.2.user.DoctorsET.post.862  1102021238    DoctorsET     862
# 3  msg_iteration.3.user.DoctorsET.post.861  1102021238    DoctorsET     861
# 4  msg_iteration.4.user.DoctorsET.post.860  1102021238    DoctorsET     860
#
#                                              message  \
# 0  https://youtu.be/5DBoEm-8kmA?si=LDLuEecNfULJVD...
# 1  ዶክተርስ ኢትዮጵያ በ አዲስ አቀራረብ በ ቴሌቪዥን ፕሮግራሙን ለመጀመር ከ...
# 2  ሞት በስኳር \n\nለልጆቻችን የምናሲዘው ምሳቃ ሳናቀው እድሚያቸውን ይቀን...
# 3  ከ HIV የተፈወሰ ሰው አጋጥሟችሁ ያቃል ? ፈውስ እና ህክምና ?\n\nሙ...
# 4  በቅርብ ጊዜ በሃገራችን ላይ እየተስተዋለ ያለ የተመሳሳይ ፆታ ( Homos...
#
#                                      cleaned_message  \
# ...

# %%
# Analyze EAHCI dataset
print("Analyzing EAHCI dataset")
analyze_data('../telegram_data_scrapper/output/data/EAHCI.csv')
print("="*80)
# Out:
# Analyzing EAHCI dataset
# Data from ../telegram_data_scrapper/output/data/EAHCI.csv
#
# Head of the DataFrame:
#                               signature  channel_id channel_name  msg_id  \
# 0  msg_iteration.0.user.EAHCI.post.2156  1432982009        EAHCI    2156
# 1  msg_iteration.1.user.EAHCI.post.2155  1432982009        EAHCI    2155
# 2  msg_iteration.2.user.EAHCI.post.2154  1432982009        EAHCI    2154
# 3  msg_iteration.3.user.EAHCI.post.2152  1432982009        EAHCI    2152
# 4  msg_iteration.4.user.EAHCI.post.2151  1432982009        EAHCI    2151
#
#                                              message  \
# 0  💥የሞያ ፈቃድ በቅርቡ ለምታሳድሱ💥               \n\n#CPD_(...
# 1                                                NaN
# 2  #💥የግርዛት_ስልጠና_Addis_Ababa & nekemte\n#Circumcis...
# 3  #💥የግርዛት_ስልጠና_Addis_Ababa\n#Circumcision_Skill_...
# 4  #💥የግርዛት_ስልጠና_Addis_Ababa\n#Circumcision_Skill_...
#
#                                      cleaned_message  \
# ...

# %%
# Analyze EAHCI dataset
print("Analyzing EAHCI dataset")
analyze_data('../telegram_data_scrapper/output/data/EAHCI.csv')
print("="*80)
# Out:
# Analyzing EAHCI dataset
# Data from ../telegram_data_scrapper/output/data/EAHCI.csv
#
# Head of the DataFrame:
#                               signature  channel_id channel_name  msg_id  \
# 0  msg_iteration.0.user.EAHCI.post.2156  1432982009        EAHCI    2156
# 1  msg_iteration.1.user.EAHCI.post.2155  1432982009        EAHCI    2155
# 2  msg_iteration.2.user.EAHCI.post.2154  1432982009        EAHCI    2154
# 3  msg_iteration.3.user.EAHCI.post.2152  1432982009        EAHCI    2152
# 4  msg_iteration.4.user.EAHCI.post.2151  1432982009        EAHCI    2151
#
#                                              message  \
# 0  💥የሞያ ፈቃድ በቅርቡ ለምታሳድሱ💥               \n\n#CPD_(...
# 1                                                NaN
# 2  #💥የግርዛት_ስልጠና_Addis_Ababa & nekemte\n#Circumcis...
# 3  #💥የግርዛት_ስልጠና_Addis_Ababa\n#Circumcision_Skill_...
# 4  #💥የግርዛት_ስልጠና_Addis_Ababa\n#Circumcision_Skill_...
#
#                                      cleaned_message  \
# ...

# %%
# Analyze EAHCI dataset
print("Analyzing EAHCI dataset")
analyze_data('../telegram_data_scrapper/output/data/EAHCI.csv')
print("="*80)
# Out:
# Analyzing EAHCI dataset
# Data from ../telegram_data_scrapper/output/data/EAHCI.csv
#
# Head of the DataFrame:
#                               signature  channel_id channel_name  msg_id  \
# 0  msg_iteration.0.user.EAHCI.post.2156  1432982009        EAHCI    2156
# 1  msg_iteration.1.user.EAHCI.post.2155  1432982009        EAHCI    2155
# 2  msg_iteration.2.user.EAHCI.post.2154  1432982009        EAHCI    2154
# 3  msg_iteration.3.user.EAHCI.post.2152  1432982009        EAHCI    2152
# 4  msg_iteration.4.user.EAHCI.post.2151  1432982009        EAHCI    2151
#
#                                              message  \
# 0  💥የሞያ ፈቃድ በቅርቡ ለምታሳድሱ💥               \n\n#CPD_(...
# 1                                                NaN
# 2  #💥የግርዛት_ስልጠና_Addis_Ababa & nekemte\n#Circumcis...
# 3  #💥የግርዛት_ስልጠና_Addis_Ababa\n#Circumcision_Skill_...
# 4  #💥የግርዛት_ስልጠና_Addis_Ababa\n#Circumcision_Skill_...
#
#                                      cleaned_message  \
# ...

# %%
# Analyze lobelia4cosmetics dataset
print("Analyzing lobelia4cosmetics dataset")
analyze_data('../telegram_data_scrapper/output/data/lobelia4cosmetics.csv')
print("="*80)
# Out:
# Analyzing lobelia4cosmetics dataset
# Data from ../telegram_data_scrapper/output/data/lobelia4cosmetics.csv
#
# Head of the DataFrame:
#                                           signature  channel_id  \
# 0  msg_iteration.0.user.lobelia4cosmetics.post.9437  1666492664
# 1  msg_iteration.1.user.lobelia4cosmetics.post.9436  1666492664
# 2  msg_iteration.2.user.lobelia4cosmetics.post.9435  1666492664
# 3  msg_iteration.3.user.lobelia4cosmetics.post.9434  1666492664
# 4  msg_iteration.4.user.lobelia4cosmetics.post.9433  1666492664
#
#         channel_name  msg_id  \
# 0  lobelia4cosmetics    9437
# 1  lobelia4cosmetics    9436
# 2  lobelia4cosmetics    9435
# 3  lobelia4cosmetics    9434
# 4  lobelia4cosmetics    9433
#
#                                              message  \
# 0  CENTRUM ADULT 50+ 200 GUMMIES \nPrice 5700 bir...
# 1  OMEGA 3 200 SOFTGELS \nPrice 5000 birr \nTeleg...
# 2  OMEGA 3,6,9 150 SOFTGELS \nPrice 5000 birr \nT...
# ...

# %%
# Analyze EAHCI dataset
print("Analyzing EAHCI dataset")
analyze_data('../telegram_data_scrapper/output/data/EAHCI.csv')
print("="*80)
# Out:
# Analyzing EAHCI dataset
# Data from ../telegram_data_scrapper/output/data/EAHCI.csv
#
# Head of the DataFrame:
#                               signature  channel_id channel_name  msg_id  \
# 0  msg_iteration.0.user.EAHCI.post.2156  1432982009        EAHCI    2156
# 1  msg_iteration.1.user.EAHCI.post.2155  1432982009        EAHCI    2155
# 2  msg_iteration.2.user.EAHCI.post.2154  1432982009        EAHCI    2154
# 3  msg_iteration.3.user.EAHCI.post.2152  1432982009        EAHCI    2152
# 4  msg_iteration.4.user.EAHCI.post.2151  1432982009        EAHCI    2151
#
#                                              message  \
# 0  💥የሞያ ፈቃድ በቅርቡ ለምታሳድሱ💥               \n\n#CPD_(...
# 1                                                NaN
# 2  #💥የግርዛት_ስልጠና_Addis_Ababa & nekemte\n#Circumcis...
# 3  #💥የግርዛት_ስልጠና_Addis_Ababa\n#Circumcision_Skill_...
# 4  #💥የግርዛት_ስልጠና_Addis_Ababa\n#Circumcision_Skill_...
#
#                                      cleaned_message  \
# ...

# %%
# Analyze yetenaweg dataset
print("Analyzing yetenaweg dataset")
analyze_data('../telegram_data_scrapper/output/data/yetenaweg.csv')
print("="*80)
# Out:
# Analyzing yetenaweg dataset
# Data from ../telegram_data_scrapper/output/data/yetenaweg.csv
#
# Head of the DataFrame:
#                                   signature  channel_id channel_name  msg_id  \
# 0  msg_iteration.1.user.yetenaweg.post.1082  1447066276    yetenaweg    1082
# 1  msg_iteration.2.user.yetenaweg.post.1081  1447066276    yetenaweg    1081
# 2  msg_iteration.4.user.yetenaweg.post.1079  1447066276    yetenaweg    1079
# 3  msg_iteration.5.user.yetenaweg.post.1078  1447066276    yetenaweg    1078
# 4  msg_iteration.6.user.yetenaweg.post.1077  1447066276    yetenaweg    1077
#
#                                              message  \
# 0                                       ጥያቄያችሁን አጋሩን
# 1  https://t.me/yetenaweg?livestream\n\nስለ ኩላሊት ጤ...
# 2                                                NaN
# 3  📣በዚህ እሁድ በቴሌግራም ቀጥታ ስርጭት የኩላሊት በሽታ ክትትል እና የዳያ...
# 4  https://www.clubhouse.com/room/xlOVk34E?utm_me...
#
#                                      cleaned_message  \
# ...

# %%
# Analyze imageoflobeli dataset
print("Analyzing imageoflobeli dataset")
analyze_data('imageoflobeli.csv')
print("="*80)
# Out:
# Analyzing imageoflobeli dataset
# Data from imageoflobeli.csv
#
# Head of the DataFrame:
#    2.550000000000000000e+02  2.550000000000000000e+02.1  \
# 0                     255.0                       255.0
# 1                       8.0                        20.0
# 2                     255.0                       255.0
# 3                     255.0                       255.0
# 4                     255.0                       255.0
#
#    2.550000000000000000e+02.2  2.550000000000000000e+02.3  \
# 0                       255.0                       255.0
# 1                         3.0                        11.0
# 2                       255.0                       255.0
# 3                       255.0                       255.0
# 4                       255.0                       255.0
#
#    2.550000000000000000e+02.4  2.550000000000000000e+02.5  \
# 0                       255.0                       255.0
# 1                         7.0                        11.0
# ...
